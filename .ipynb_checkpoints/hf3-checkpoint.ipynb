# %% [markdown]
# # Predict Magnetic Structure

# %%
import re
import copy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
from pyhf3.read import ReadInfo
from pyhf3 import magstr

name = 'baoso3'
input_path = 'input/%s/' % name
output_path = 'output/%s/' % name

path_info, type_info = ReadInfo(input_path)
for key, val in type_info.items():
    if val == 's': type_info[key] = 6
    else: type_info[key] = 12

# %%
def DrawHeatmap(output_path, fs):
    df = pd.read_csv('%s/%s' % (output_path, fs))
    #df = df[df['bins'] != 10]
    #df = df[df['eta'] != 0.1]
    bins_range = sorted(list(set(df['bins'])))
    eta_range = sorted(list(set(df['eta'])))
    
    df = df.sort_values(by=['bins', 'eta'])
    data = df['acc'].to_numpy().reshape((len(bins_range), len(eta_range))).T
    
    fig, ax = plt.subplots(figsize=(14, 6))
    ms = ax.matshow(data, cmap='Blues')
    cb = plt.colorbar(ms, shrink=0.9, format='%.2f')
    
    acc_max = 0
    coord = (0, 0)
    for (i, j), z in np.ndenumerate(data):
        #ax.text(j, i, '{:0.2f}'.format(z), size=13, ha='center', va='center', c='white')
        if z > acc_max:
            acc_max = z
            coord = (j, i)
            
    #ax.text(coord[0], coord[1], '{:0.2f}'.format(acc_max), size=13, ha='center', va='center', c='white')
    ax.scatter(coord[0], coord[1], s=150, c='white', marker='*')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(range(0, len(bins_range)))
    ax.set_yticks(range(0, len(eta_range)))
    ax.set_xticklabels(bins_range, rotation=45)
    ax.set_yticklabels(eta_range)
    ax.set_xlabel('Interval')
    ax.set_ylabel('Broadening scale')
    print(coord, acc_max)
    plt.show()
    
def DrawOptEta(output_path, fs, bins):
    df = pd.read_csv('%s/%s' % (output_path, fs))
    df = df[df['bins'] == bins]
    data = df[['eta', 'acc']].to_numpy()
    
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(data[:, 0], data[:, 1], '.-', ms=20)
    ax.grid(True)
    yticks = [i for i in np.arange(0.90, 0.97, 0.01)]
    ax.set_yticks(yticks)
    ax.set_yticklabels(['%.2f' % i for i in yticks])
    ax.set_xlabel('Broadening scale')
    ax.set_ylabel('Accuracy')
    plt.show()
            
def DrawConfusionMatrix(y_test, y_pred):
    ConfusionMatrixDisplay.from_predictions(y_test, y_pred, normalize='true', cmap='Blues', values_format='.2f')
    plt.show()

# %%
m = magstr.ML(output_path, path_info, type_info)
df, e_label, w_label, p_labe = m.OpenBand()
df
# Out:
#        JU  SOC type     N    U         m      fermi      dntop       gap  \
# 0     0.0  0.0    a   1.2  3.5  0.062527   5.727997   5.727292  0.000824
# 1     0.0  0.0    a   1.2  5.0  0.081950   6.476934   6.476348  0.001770
# 2     0.0  0.0    a   1.4  5.0  1.398497   5.728491   5.728334  0.000183
# 3     0.0  0.0    c   1.6  4.5  1.433597   5.645409   5.644392  0.001117
# 4     0.0  0.0    a   1.6  5.0  1.598612   5.913318   5.913228  0.000128
# ...   ...  ...  ...   ...  ...       ...        ...        ...       ...
# 1582  0.3  0.0    a  11.4  5.0  0.407585  15.932199  15.932090  0.000120
# 1583  0.3  0.0    a  11.6  3.5  0.023704  13.158365  13.158279  0.000689
# 1584  0.3  0.0    a  11.6  4.0  0.095297  14.128582  14.128541  0.000186
# 1585  0.3  0.0    a  11.6  4.5  0.143108  15.110250  15.110078  0.000191
# 1586  0.3  0.0    a  11.6  5.0  0.170619  16.090321  16.090089  0.000406
#
#            eG0  ...       wR2       wR3       wR4       wR5       wR6  \
# 0    -1.173208  ...  0.000000  0.000000  0.018139  0.018139  1.000000
# 1    -1.194727  ...  0.000000  0.000000  0.056602  0.056602  1.000000
# 2    -2.844334  ...  0.000000  0.000000  0.000000  0.000000  0.556378
# 3    -1.658659  ...  0.878656  0.878656  0.000000  0.000000  0.000000
# 4    -3.029293  ...  0.000000  0.000000  0.000000  0.000000  0.549399
# ...        ...  ...       ...       ...       ...       ...       ...
# 1582 -3.954648  ...  0.044099  0.044099  0.260815  0.260815  0.955906
# 1583 -3.575911  ...  0.000062  0.000062  0.001928  0.001928  0.999933
# 1584 -3.616054  ...  0.001321  0.001321  0.035903  0.035903  0.998679
# 1585 -3.684017  ...  0.003844  0.003844  0.084394  0.084394  0.996156
# 1586 -3.738663  ...  0.006967  0.006967  0.122490  0.122490  0.993034
#
#            wR7       wR8       wR9      wR10      wR11
# 0     1.000000  1.000000  1.000000  0.981861  0.981861
# 1     1.000000  1.000000  1.000000  0.943398  0.943398
# 2     0.556378  1.000000  1.000000  1.000000  1.000000
# 3     0.000000  1.000000  1.000000  1.000000  1.000000
# 4     0.549399  1.000000  1.000000  1.000000  1.000000
# ...        ...       ...       ...       ...       ...
# 1582  0.955906  0.955901  0.955901  0.739185  0.739185
# 1583  0.999933  0.999938  0.999938  0.998078  0.998078
# 1584  0.998679  0.998679  0.998679  0.964097  0.964097
# 1585  0.996156  0.996156  0.996156  0.915606  0.915606
# 1586  0.993034  0.993033  0.993033  0.877510  0.877510
#
# [1587 rows x 105 columns]

# %%
plt.rcParams.update({'font.size': 15})

bins = 120
info = plt.hist(df.loc[:, e_label].values.flatten(), bins=bins, density=True)
energy_range = [min(info[1]), max(info[1])]

plt.xlabel('Energy')
plt.ylabel('DOS')
plt.show()

# %%
plt.rcParams.update({'font.size': 18})

DrawHeatmap(output_path, 'magstr/acc_rf.csv')
# Out:
# (3, 5) 0.962264

# %%
plt.rcParams.update({'font.size': 18})

DrawOptEta(output_path, 'magstr/acc_rf.csv', 40)

# %%
plt.rcParams.update({'font.size': 16})

acc, y_test, y_pred = m.DoRandomForest(100, 0.4)
DrawConfusionMatrix(y_test, y_pred)

# %%
y_test.iloc[0]
# Out:
# 'g'

# %%
df0, e_label, w_label, p_label = m.OpenBand()
mis_list = []
cor_list = []

for i, y_true in enumerate(y_test):
    if(y_true != y_pred[i]):
# 729   0.1  0.0    c  10.2  3.5  1.606087  19.069453  19.068021  0.002361

# %%
print(len(df_cor[df_cor['gap'] < 0.001]))
# Out:
# 289

# %%
bins = 5
plt.hist(df['gap'], bins=bins)
plt.hist(df_mis['gap'], range=(min(df['gap']), max(df['gap'])), bins=bins)
plt.show()

# %%
df0, e_label, w_label, p_label = m.OpenBand()
idx_list = []

for i, y_true in enumerate(y_test):
    if(y_true == 'c' and y_pred[i] == 'a'):
        idx_list.append(y_test.index[i])

df_ca = df0.loc[idx_list, p_label]
df_ca
# Out:
#        JU  SOC type     N    U         m      fermi      dntop       gap
# 437   0.1  0.0    c   3.6  1.5  0.009358   6.741777   6.741737  0.000236
# 675   0.1  0.0    c   9.0  1.0  0.001825   8.814229   8.813982  0.000584
# 665   0.1  0.0    c   8.6  4.5  3.279803  20.000013  19.999421  0.001169
# 648   0.1  0.0    c   8.2  4.5  3.682539  19.574259  19.573250  0.001321
# 236   0.0  0.0    c   7.8  2.0  3.388617  12.209661  12.209621  0.001056
# 1094  0.2  0.0    c   9.4  1.0  0.002848   8.228571   8.228394  0.000211
# 728   0.1  0.0    c  10.2  3.0  1.547957  17.070800  17.068693  0.003066
# 120   0.0  0.0    c   5.2  2.5  3.873561  10.646923  10.646910  0.000113
# 333   0.0  0.0    c  10.2  2.5  1.460721  17.568109  17.567733  0.002777
# 317   0.0  0.0    c   9.8  1.5  0.369285  12.075037  12.074332  0.001395
# 47    0.0  0.0    c   3.4  2.0  0.227871   7.747901   7.747865  0.000056
# 126   0.0  0.0    c   5.4  1.0  0.400770   7.628723   7.628588  0.000242
# 729   0.1  0.0    c  10.2  3.5  1.606087  19.069453  19.068021  0.002361

# %%
df_ca.sort_values(by=['N', 'U'])
# Out:
#        JU  SOC type     N    U         m      fermi      dntop       gap
# 47    0.0  0.0    c   3.4  2.0  0.227871   7.747901   7.747865  0.000056
# 437   0.1  0.0    c   3.6  1.5  0.009358   6.741777   6.741737  0.000236
# 120   0.0  0.0    c   5.2  2.5  3.873561  10.646923  10.646910  0.000113
# 126   0.0  0.0    c   5.4  1.0  0.400770   7.628723   7.628588  0.000242
# 236   0.0  0.0    c   7.8  2.0  3.388617  12.209661  12.209621  0.001056
# 648   0.1  0.0    c   8.2  4.5  3.682539  19.574259  19.573250  0.001321
# 665   0.1  0.0    c   8.6  4.5  3.279803  20.000013  19.999421  0.001169
# 675   0.1  0.0    c   9.0  1.0  0.001825   8.814229   8.813982  0.000584
# 1094  0.2  0.0    c   9.4  1.0  0.002848   8.228571   8.228394  0.000211
# 317   0.0  0.0    c   9.8  1.5  0.369285  12.075037  12.074332  0.001395
# 333   0.0  0.0    c  10.2  2.5  1.460721  17.568109  17.567733  0.002777
# 728   0.1  0.0    c  10.2  3.0  1.547957  17.070800  17.068693  0.003066
# 729   0.1  0.0    c  10.2  3.5  1.606087  19.069453  19.068021  0.002361
